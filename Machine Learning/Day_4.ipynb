# %% [markdown]
# Gradient Descent example w/ different iterations and learning rate

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from matplotlib import pyplot as plt

# %%
X = 2 * np.random.rand(1000, 1)
y = 4 + 3 * X + np.random.randn(1000, 1) # to add some noise to the data
y_clean = 4 + 3 * X

# %%
 GD_model = SGDRegressor(max_iter=1000, eta0=0.001)
GD_model.fit(X, y.squeeze())
# Out:
# SGDRegressor(eta0=0.001)

# %%
y_hat = GD_model.predict(X)
GD_model.intercept_, GD_model.coef_
# Out:
# (array([3.43360953]), array([3.49011297]))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y, y_hat)
# Out:
# 1.05741007180739

# %%
GD_model.n_iter_no_change
# Out:
# 5

# %%
 X_b = np.linspace(X.min(), X.max(), 10).reshape(-1, 1)

# %%
def model_ex(max_iter=0, lr=0, line_style=None):
    _model = SGDRegressor(max_iter=max_iter, eta0=lr)
    _model_fit = _model.fit(X, y)
    _y_hat = _model_fit.predict(X)
    mse = mean_squared_error(y_clean, _y_hat)
    print(f"MSE: {mse}")
    _y_hat_b = _model_fit.predict(X_b)
    line_style["label"] += f" - MSE={mse:0.4f}"
    plt.plot(X_b, _y_hat_b, **line_style)

# %%
plt.figure(figsize=(10,7))
plt.scatter(X, y)
plt.ylabel("y")
plt.xlabel("X")
# # plt.plot(X_b, y_hat_b)
model_ex(1, 0.001, {"color":"red", "label":"lr=0.001 - itter=1"})
model_ex(3, 0.001, {"color":"green", "label":"lr=0.001 - itter=3"})
model_ex(5, 0.001, {"color":"yellow", "label":"lr=0.001 - itter=5"})
model_ex(10, 0.001, {"color":"black", "label":"lr=0.001 - itter=10"})
model_ex(100, 0.001, {"color":"blue", "label":"lr=0.001 - itter=100"})
plt.legend()
# Out:
# MSE: 18.35785484067809
# MSE: 4.872286234265201
# MSE: 1.6845973400035794
# MSE: 0.26404474329574734
# MSE: 0.08452991897431104
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1548: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
plt.figure(figsize=(10,7))
plt.scatter(X, y)
plt.ylabel("y")
plt.xlabel("X")
# # plt.plot(X_b, y_hat_b)
model_ex(1, 0.005, {"color":"red", "label":"lr=0.001 - itter=1"})
model_ex(3, 0.005, {"color":"green", "label":"lr=0.001 - itter=3"})
model_ex(5, 0.005, {"color":"yellow", "label":"lr=0.001 - itter=5"})
model_ex(10, 0.005, {"color":"black", "label":"lr=0.001 - itter=10"})
model_ex(100, 0.005, {"color":"blue", "label":"lr=0.001 - itter=100"})
plt.legend()
# Out:
# MSE: 0.3816336436275657
# MSE: 0.11116534251712708
# MSE: 0.07726265177771853
# MSE: 0.034949058860805106
# MSE: 0.013057189263646086
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1548: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
plt.figure(figsize=(10,7))
plt.scatter(X, y)
plt.ylabel("y")
plt.xlabel("X")
# # plt.plot(X_b, y_hat_b)
model_ex(150, 0.001, {"color":"red", "label":"lr=0.001 - itter=150"})
model_ex(350, 0.001, {"color":"green", "label":"lr=0.001 - itter=350"})
model_ex(500, 0.001, {"color":"yellow", "label":"lr=0.001 - itter=500"})
model_ex(666, 0.001, {"color":"black", "label":"lr=0.001 - itter=666"})
model_ex(1000, 0.001, {"color":"blue", "label":"lr=0.001 - itter=1000"})
plt.legend()
# Out:
# MSE: 0.0868431811068913
# MSE: 0.0861644863779483
# MSE: 0.08572792925108412
# MSE: 0.08510996051553105
# MSE: 0.08652217219659775
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
plt.figure(figsize=(10,7))
plt.scatter(X, y)
plt.ylabel("y")
plt.xlabel("X")
# # plt.plot(X_b, y_hat_b)
model_ex(150, 0.005, {"color":"red", "label":"lr=0.001 - itter=150"})
model_ex(350, 0.005, {"color":"green", "label":"lr=0.001 - itter=350"})
model_ex(500, 0.005, {"color":"yellow", "label":"lr=0.001 - itter=500"})
model_ex(666, 0.005, {"color":"black", "label":"lr=0.001 - itter=666"})
model_ex(1000, 0.005, {"color":"blue", "label":"lr=0.001 - itter=1000"})
plt.legend()
# Out:
# MSE: 0.013413880043414135
# MSE: 0.013590165399448639
# MSE: 0.012900595531368866
# MSE: 0.01424612027432216
# MSE: 0.012607889111146943
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
